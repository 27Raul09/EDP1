# %% [markdown]
# <a href="https://colab.research.google.com/github/27Raul09/EDP1/blob/main/tarea%202%2C%20problema%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pylab import *

# %%
def u_x_y(x,y,N=8): 
  f = zeros( (len(x),len(y)) ) 
  for i in range(len(y)): 
    for n in range(1,N): 
      a=-2*(1-cos(n*pi))/((n*pi)**2*cosh(n*pi))
      f[:,i] += a*sin(n*pi*x)*sinh(n*pi*y[i])
  return f

# %%
#%matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection="3d")

x = linspace(0,1.0,100)
y = linspace(0,1.0,100)

X,Y = np.meshgrid(x,y)

U = u_x_y(x,y)

plt.xlabel('$y$'); plt.ylabel('$x$'); 
plt.title("u(x,y)")
ax.plot_surface(X, Y, U, cmap="inferno"); #Otros colores:"viridis", "inferno", "plasma"
